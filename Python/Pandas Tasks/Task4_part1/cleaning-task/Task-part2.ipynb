# %% [markdown]
# ![image.jpeg](PlayStore.jpeg)

# %% [markdown]
# ## Analysis And Visualizations
# **Remember the csv file you created in the last task ? Now it's time to use it for some analysis and visualizations**
#
# **Note: each question will be answered into 2 parts first your analysis using pandas and then use visualizations to prove it**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("filteredplaystore.csv")

# %% [markdown]
# ### 11. Which app has the greatest number of reviews?

# %% [markdown]
# ### 1. Analysis

# %%
# Find the app with the maximum number of reviews
max_reviews_idx = df['Reviews'].idxmax()
app_with_max_reviews = df.loc[max_reviews_idx, 'App']
print("App with the greatest number of reviews:", app_with_max_reviews)
# Out:
# App with the greatest number of reviews: Facebook

# %% [markdown]
# ### 2. Visualization

# %%
sns.barplot(data=df.sort_values('Reviews', ascending=False).head(10),x='Reviews', y='App', palette='viridis')
plt.title("Top 10 Apps by Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("App")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\2761042707.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df.sort_values('Reviews', ascending=False).head(10),x='Reviews', y='App', palette='viridis')

# %% [markdown]
# ### 12. What Category Has the Highest Number of Apps Uploaded to the Store?
#
# Get the specific category that contains the most significant number of uploaded applications.

# %% [markdown]
# ### 1. Analysis

# %%
# Count number of apps per category
category_counts = df['Category'].value_counts()
max_category = category_counts.idxmax()
print("Category with the highest number of apps:", max_category)
# Out:
# Category with the highest number of apps: Family

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(12, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title("Number of Apps by Category")
plt.xlabel("Category")
plt.ylabel("Count of Apps")
plt.axhline(y=category_counts[max_category], color='red', linestyle='--', label=f"Max: {max_category}")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 13. To Which Category Belongs the Most Expensive App?

# %% [markdown]
# ### 1. Analysis

# %%
# Find the app with the highest price 
max_price_idx = df['Price'].idxmax()
expensive_app_category = df.loc[max_price_idx, 'Category']
print("The most expensive app belongs to the category:", expensive_app_category)
# Out:
# The most expensive app belongs to the category: Lifestyle

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Category', y='Price', alpha=0.5)
plt.xticks(rotation=90)
# Highlight the most expensive app
expensive_app = df.loc[max_price_idx]
plt.scatter(expensive_app['Category'], expensive_app['Price'], color='red', s=100, label="Most Expensive App")
plt.title("Price of Apps by Category")
plt.xlabel("Category")
plt.ylabel("Price")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 14. What's the Name of the Most Expensive Game?
#
# Find the most expensive app in the Game category and enter its name.

# %% [markdown]
# ### 1. Analysis

# %%
# Filter apps that are in the 'Game' category 
games_df = df[df['Category'] == 'Game']

# Find the game with the highest price
if not games_df.empty:
    max_price_game_idx = games_df['Price'].idxmax()
    most_expensive_game = games_df.loc[max_price_game_idx, 'App']
    print("The most expensive game is:", most_expensive_game)
else:
    print("No apps found in the Game category.")
# Out:
# The most expensive game is: The World Ends With You

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=games_df.sort_values(by='Price', ascending=False).head(10), x='Price', y='App', palette='magma')
plt.title("Top 10 Most Expensive Games")
plt.xlabel("Price")
plt.ylabel("Game")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\4092323822.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=games_df.sort_values(by='Price', ascending=False).head(10), x='Price', y='App', palette='magma')

# %% [markdown]
# ### 15. Which Is the Most Popular Finance App?
#
# What app (from the Finance category) has the most installs?

# %% [markdown]
# ### 1. Analysis

# %%
# Filter apps in the Finance category
finance_df = df[df['Category'] == 'Finance']

# Find the app with the highest number of installs in Finance
if not finance_df.empty:
    max_installs_finance_idx = finance_df['Installs'].idxmax()
    most_popular_finance_app = finance_df.loc[max_installs_finance_idx, 'App']
    print("The most popular Finance app is:", most_popular_finance_app)
else:
    print("No apps found in the Finance category.")
# Out:
# The most popular Finance app is: Google Pay

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(10, 6))
sorted_finance = finance_df.sort_values(by='Installs', ascending=False).head(10)
sns.barplot(data=sorted_finance, x='Installs', y='App', palette='coolwarm')
plt.title("Top 10 Finance Apps by Installs")
plt.xlabel("Installs")
plt.ylabel("App")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\2271592758.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sorted_finance, x='Installs', y='App', palette='coolwarm')

# %% [markdown]
# ### 16. What Teen Game Has the Most Reviews?
#
# What app from the Game category and catalogued as Teen in Content Rating has the most reviews?

# %% [markdown]
# ### 1. Analysis

# %%
# Filter apps that are in the Game category and have 'Teen' as Content Rating
teen_game_df = df[(df['Category'] == 'Game') & (df['Content Rating'] == 'Teen')]

# Find the game with the maximum reviews in this subset
if not teen_game_df.empty:
    max_reviews_teen_game_idx = teen_game_df['Reviews'].idxmax()
    most_reviewed_teen_game = teen_game_df.loc[max_reviews_teen_game_idx, 'App']
    print("The Teen game with the most reviews is:", most_reviewed_teen_game)
else:
    print("No Teen games found in the dataset.")
# Out:
# The Teen game with the most reviews is: Asphalt 8: Airborne

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(10, 6))
sorted_teen_games = teen_game_df.sort_values(by='Reviews', ascending=False).head(10)
sns.barplot(data=sorted_teen_games, x='Reviews', y='App', palette='viridis')
plt.title("Top 10 Teen Games by Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Game")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\152398440.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sorted_teen_games, x='Reviews', y='App', palette='viridis')

# %% [markdown]
# ### 17. Which Is the Free Game with the Most Reviews?
#
#  Get the name of the free game app with the most reviews.

# %% [markdown]
# ### 1. Analysis

# %%
# Filter apps in the Game category that are free (Distribution == 'Free')
free_game_df = df[(df['Category'] == 'Game') & (df['Distribution'] == 'Free')]

# Find the free game with the maximum reviews
if not free_game_df.empty:
    max_reviews_free_game_idx = free_game_df['Reviews'].idxmax()
    most_reviewed_free_game = free_game_df.loc[max_reviews_free_game_idx, 'App']
    print("The free game with the most reviews is:", most_reviewed_free_game)
else:
    print("No free games found in the dataset.")
# Out:
# The free game with the most reviews is: Clash of Clans

# %% [markdown]
# ### 2. Visualization

# %%
plt.figure(figsize=(10, 6))
sorted_free_games = free_game_df.sort_values(by='Reviews', ascending=False).head(10)
sns.barplot(data=sorted_free_games, x='Reviews', y='App', palette='rocket')
plt.title("Top 10 Free Games by Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Game")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\1084049752.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sorted_free_games, x='Reviews', y='App', palette='rocket')

# %% [markdown]
# ### 18. How many Tb (tebibytes) were transferred (overall) for the most popular Lifestyle app?
#
# This app produced the greatest amount of bytes transfer. Enter your answer in Tebibytes as a whole number (rounding down to the nearest integer). Example, if you find the total transfer to be 780.9581 Tb, just enter 780.
#
# - Find the total size by multiplying size of the app with total installs and convert the result into TB.

# %% [markdown]
# - we need to compute the total data transferred (in bytes) for an app by multiplying its size (in bytes) by its number of installs. Then, convert this total to Tebibytes (TiB), where 1 TiB = 2^40 bytes ( 1,099,511,627,776 bytes).

# %% [markdown]
# ### 1. Analysis

# %%
import math

# Filter for Lifestyle category
lifestyle_df = df[df['Category'] == 'Lifestyle']

if not lifestyle_df.empty:   
    max_installs_lifestyle_idx = lifestyle_df['Installs'].idxmax()
    most_popular_lifestyle_app = lifestyle_df.loc[max_installs_lifestyle_idx]
    
    # Calculate total transferred bytes = Size (in bytes) * Installs
    total_bytes_transferred = most_popular_lifestyle_app['Size'] * most_popular_lifestyle_app['Installs']
    
    # Convert bytes to Tebibytes (TiB)
    bytes_per_tib = 2 ** 40  # 1,099,511,627,776 bytes in 1 TiB
    tib_transferred = total_bytes_transferred // bytes_per_tib  # rounding down to the nearest integer
    
    print("The most popular Lifestyle app is:", most_popular_lifestyle_app['App'])
    print("Total bytes transferred (in TiB):", tib_transferred)
else:
    print("No apps found in the Lifestyle category.")
# Out:
# The most popular Lifestyle app is: Tinder
# Total bytes transferred (in TiB): 6484

# %% [markdown]
# ### 2. Visualization

# %%
lifestyle_df = lifestyle_df.copy()
bytes_per_tib = 2 ** 40
lifestyle_df['Total_TiB'] = (lifestyle_df['Size'] * lifestyle_df['Installs']) // bytes_per_tib

# Sort by Total_TiB and select top 10
top_lifestyle = lifestyle_df.sort_values(by='Total_TiB', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top_lifestyle, x='Total_TiB', y='App', palette='flare')
plt.title("Top 10 Lifestyle Apps by Total Data Transferred (TiB)")
plt.xlabel("Total Transferred Data (TiB)")
plt.ylabel("App")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\3782085537.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_lifestyle, x='Total_TiB', y='App', palette='flare')
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\3782085537.py:13: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\3782085537.py:13: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Basmala\AppData\Local\Temp\ipykernel_828\3782085537.py:13: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
